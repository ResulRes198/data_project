# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
data=pd.read_excel("C:/Users/umutg/Desktop/co2.xls")

# %%
data=data.dropna()
data.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6'],
#       dtype='object')

# %%
df=data.rename(columns={"Unnamed: 0":"Year","Unnamed: 1":"Total","Unnamed: 2":"Change","Unnamed: 3":"Energy","Unnamed: 4":"Industry","Unnamed: 5":"Agriculture","Unnamed: 6":"Waste"})

# %%
df_1=df.drop(labels=2,axis=0)

# %%
"""df_by_year = df_1.groupby("Year").sum()
df_by_year.plot(kind="bar", figsize=(15,15))
plt.title("Greenhouse gas emissions in Turkey")
plt.xlabel("Year")
plt.ylabel("Emissions (million metric tons of CO2 equivalent)")

plt.show()"""
# Out:
# 'df_by_year = df_1.groupby("Year").sum()\ndf_by_year.plot(kind="bar", figsize=(15,15))\nplt.title("Greenhouse gas emissions in Turkey")\nplt.xlabel("Year")\nplt.ylabel("Emissions (million metric tons of CO2 equivalent)")\n\nplt.show()'

# %%
plt.figure(figsize=(8, 10))
plt.title("Greenhouse gas emissions in Turkey")
plt.xlabel("Year")
plt.ylabel("Emissions (million metric tons of CO2 equivalent)")

plt.plot(df_1["Year"], df_1["Total"], label="Total")
plt.plot(df_1["Year"], df_1["Energy"], label="Energy")
plt.plot(df_1["Year"], df_1["Industry"], label="Industry")
plt.plot(df_1["Year"], df_1["Agriculture"], label="Agriculture")
plt.plot(df_1["Year"], df_1["Waste"], label="Waste")
plt.legend()
plt.show()

# %%
colums=["Total","Energy","Industry","Agriculture","Waste"]

df_1.plot(kind="bar", stacked=True, figsize=(10, 5), title="Energy Consumption by Sector", y=colums,x="Year")

plt.show()
